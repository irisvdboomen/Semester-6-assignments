# %%
import pandas as pd
display.max_rows = None
display.max_columns = None

# # Load the datasets
# file_path1 = 'iris_timed_data.csv'
# file_path2 = 'mostrecent_data.csv'

file_path1 = 'timed_data-Iris2.csv'
file_path2 = 'Inwoners naar kenmerken - Buurten.csv'

# Reading the datasets
dataset1 = pd.read_csv(file_path1)
dataset2 = pd.read_csv(file_path2)

dataset1, dataset2
# Out:
# (     NbId                      NbName  DistrictId             DistrictName  \
#  0     522  Achtse Barrier-Gunterslaer           5  Stadsdeel Woensel-Noord
#  1     524       Achtse Barrier-Hoeven           5  Stadsdeel Woensel-Noord
#  2     523    Achtse Barrier-Spaaihoef           5  Stadsdeel Woensel-Noord
#  3     423                     Barrier           4   Stadsdeel Woensel-Zuid
#  4     631                        BeA2           6         Stadsdeel Strijp
#  ..    ...                         ...         ...                      ...
#  111   531             Woenselse Heide           5  Stadsdeel Woensel-Noord
#  112   414        Woenselse Watermolen           4   Stadsdeel Woensel-Zuid
#  113   421                Woensel-West           4   Stadsdeel Woensel-Zuid
#  114   634                    Zandrijk           6         Stadsdeel Strijp
#  115   625                 Zwaanstraat           6         Stadsdeel Strijp
#
# ...

# %%
# Let's try to read the first dataset with a semi-colon delimiter to see if it resolves the format issue.
try:
    dataset2 = pd.read_csv(file_path2, delimiter=';')
except Exception as e:
    dataset2_error = str(e)
    dataset2 = None

dataset2.head(10) if dataset2 is not None else dataset2_error
# Out:
#                       Buurten Inwoners naar kenmerken|0-9 jaar|2015|Man  \
# 0  Achtse Barrier-Gunterslaer                                       175
# 1       Achtse Barrier-Hoeven                                       241
# 2    Achtse Barrier-Spaaihoef                                       293
# 3                     Barrier                                       168
# 4                        BeA2                                         x
# 5                     Beemden                                         x
# 6               Bennekel-Oost                                       159
# 7   Bennekel-West, Gagelbosch                                       158
# 8                      Bergen                                        67
# 9                  Binnenstad                                        49
#
#   Inwoners naar kenmerken|0-9 jaar|2015|Vrouw  \
# 0                                         197
# 1                                         206
# ...

# %%
# Specify which columns to select from mostrecent_data.csv
columns_to_select = ['NbId', 'NbName', 'DistrictId', 'DistrictName', 'Geoshape', 'GeoshapePerimeter', 'GeoshapeArea',
                     'GeoshapeCenter', 'Mannen|2014', 'Mannen|2015', 'Mannen|2016', 'Mannen|2017', 'Mannen|2018', 'Mannen|2019', 'Mannen|2020', 'Mannen|2021', 'Vrouwen|2014', 'Vrouwen|2015', 'Vrouwen|2016', 'Vrouwen|2017', 'Vrouwen|2018', 'Vrouwen|2019', 'Vrouwen|2020', 'Vrouwen|2021', 'Totaal 0-9 jaar|2014', 'Totaal 0-9 jaar|2015', 'Totaal 0-9 jaar|2016', 'Totaal 0-9 jaar|2017', 'Totaal 0-9 jaar|2018', 'Totaal 0-9 jaar|2019', 'Totaal 0-9 jaar|2020', 'Totaal 0-9 jaar|2021', 'Totaal 10-19 jaar|2014', 'Totaal 10-19 jaar|2015', 'Totaal 10-19 jaar|2016', 'Totaal 10-19 jaar|2017', 'Totaal 10-19 jaar|2018', 'Totaal 10-19 jaar|2019', 'Totaal 10-19 jaar|2020', 'Totaal 10-19 jaar|2021', 'Totaal 20-29 jaar|2014', 'Totaal 20-29 jaar|2015', 'Totaal 20-29 jaar|2016', 'Totaal 20-29 jaar|2017', 'Totaal 20-29 jaar|2018', 'Totaal 20-29 jaar|2019', 'Totaal 20-29 jaar|2020', 'Totaal 20-29 jaar|2021', 'Totaal 30-39 jaar|2014', 'Totaal 30-39 jaar|2015', 'Totaal 30-39 jaar|2016', 'Totaal 30-39 jaar|2017', 'Totaal 30-39 jaar|2018', 'Totaal 30-39 jaar|2019', 'Totaal 30-39 jaar|2020', 'Totaal 30-39 jaar|2021', 'Totaal 40-49 jaar|2014', 'Totaal 40-49 jaar|2015', 'Totaal 40-49 jaar|2016', 'Totaal 40-49 jaar|2017', 'Totaal 40-49 jaar|2018', 'Totaal 40-49 jaar|2019', 'Totaal 40-49 jaar|2020', 'Totaal 40-49 jaar|2021', 'Totaal 50-59 jaar|2014', 'Totaal 50-59 jaar|2015', 'Totaal 50-59 jaar|2016', 'Totaal 50-59 jaar|2017', 'Totaal 50-59 jaar|2018', 'Totaal 50-59 jaar|2019', 'Totaal 50-59 jaar|2020', 'Totaal 50-59 jaar|2021', 'Totaal 60-69 jaar|2014', 'Totaal 60-69 jaar|2015', 'Totaal 60-69 jaar|2016', 'Totaal 60-69 jaar|2017', 'Totaal 60-69 jaar|2018', 'Totaal 60-69 jaar|2019', 'Totaal 60-69 jaar|2020', 'Totaal 60-69 jaar|2021', 'Totaal 70-79 jaar|2014', 'Totaal 70-79 jaar|2015', 'Totaal 70-79 jaar|2016', 'Totaal 70-79 jaar|2017', 'Totaal 70-79 jaar|2018', 'Totaal 70-79 jaar|2019', 'Totaal 70-79 jaar|2020', 'Totaal 70-79 jaar|2021', 'Totaal 80-89 jaar|2014', 'Totaal 80-89 jaar|2015', 'Totaal 80-89 jaar|2016', 'Totaal 80-89 jaar|2017', 'Totaal 80-89 jaar|2018', 'Totaal 80-89 jaar|2019', 'Totaal 80-89 jaar|2020', 'Totaal 80-89 jaar|2021', 'Totaal 90 jaar en ouder|2014', 'Totaal 90 jaar en ouder|2015', 'Totaal 90 jaar en ouder|2016', 'Totaal 90 jaar en ouder|2017', 'Totaal 90 jaar en ouder|2018', 'Totaal 90 jaar en ouder|2019', 'Totaal 90 jaar en ouder|2020', 'Totaal 90 jaar en ouder|2021']

# Selecting the columns from mostrecent_data.csv
dataset1 = dataset1[columns_to_select]

# Renaming the 'buurten' column in dataset 2 to 'NbName' for consistency
dataset2.rename(columns={'Buurten': 'NbName'}, inplace=True)

dataset1, dataset2
# Out:
# (     NbId                      NbName  DistrictId             DistrictName  \
#  0     522  Achtse Barrier-Gunterslaer           5  Stadsdeel Woensel-Noord
#  1     524       Achtse Barrier-Hoeven           5  Stadsdeel Woensel-Noord
#  2     523    Achtse Barrier-Spaaihoef           5  Stadsdeel Woensel-Noord
#  3     423                     Barrier           4   Stadsdeel Woensel-Zuid
#  4     631                        BeA2           6         Stadsdeel Strijp
#  ..    ...                         ...         ...                      ...
#  111   531             Woenselse Heide           5  Stadsdeel Woensel-Noord
#  112   414        Woenselse Watermolen           4   Stadsdeel Woensel-Zuid
#  113   421                Woensel-West           4   Stadsdeel Woensel-Zuid
#  114   634                    Zandrijk           6         Stadsdeel Strijp
#  115   625                 Zwaanstraat           6         Stadsdeel Strijp
#
# ...

# %%
# Merging the two datasets on the 'NbName' column
merged_dataset = pd.merge(dataset1, dataset2, on='NbName', how='inner')

merged_dataset.head()
# Out:
#    NbId                      NbName  DistrictId             DistrictName  \
# 0   522  Achtse Barrier-Gunterslaer           5  Stadsdeel Woensel-Noord
# 1   524       Achtse Barrier-Hoeven           5  Stadsdeel Woensel-Noord
# 2   523    Achtse Barrier-Spaaihoef           5  Stadsdeel Woensel-Noord
# 3   423                     Barrier           4   Stadsdeel Woensel-Zuid
# 4   631                        BeA2           6         Stadsdeel Strijp
#
#                                             Geoshape  GeoshapePerimeter  \
# 0  {"coordinates": [[[5.45625536423871, 51.479033...        4710.687538
# 1  {"coordinates": [[[5.444884639883207, 51.48575...        3647.832287
# 2  {"coordinates": [[[5.439586926395638, 51.48854...        5252.710205
# 3  {"coordinates": [[[5.454851547237404, 51.46224...        2110.141942
# 4  {"coordinates": [[[5.393934485995225, 51.46433...        8769.133586
#
#    GeoshapeArea                        GeoshapeCenter Mannen|2014 Mannen|2015  \
# ...

# %%
# check if all the columns are present

column_names = merged_dataset.columns.tolist()
print(column_names)
# Out:
# ['NbId', 'NbName', 'DistrictId', 'DistrictName', 'Geoshape', 'GeoshapePerimeter', 'GeoshapeArea', 'GeoshapeCenter', 'Mannen|2014', 'Mannen|2015', 'Mannen|2016', 'Mannen|2017', 'Mannen|2018', 'Mannen|2019', 'Mannen|2020', 'Mannen|2021', 'Vrouwen|2014', 'Vrouwen|2015', 'Vrouwen|2016', 'Vrouwen|2017', 'Vrouwen|2018', 'Vrouwen|2019', 'Vrouwen|2020', 'Vrouwen|2021', 'Totaal 0-9 jaar|2014', 'Totaal 0-9 jaar|2015', 'Totaal 0-9 jaar|2016', 'Totaal 0-9 jaar|2017', 'Totaal 0-9 jaar|2018', 'Totaal 0-9 jaar|2019', 'Totaal 0-9 jaar|2020', 'Totaal 0-9 jaar|2021', 'Totaal 10-19 jaar|2014', 'Totaal 10-19 jaar|2015', 'Totaal 10-19 jaar|2016', 'Totaal 10-19 jaar|2017', 'Totaal 10-19 jaar|2018', 'Totaal 10-19 jaar|2019', 'Totaal 10-19 jaar|2020', 'Totaal 10-19 jaar|2021', 'Totaal 20-29 jaar|2014', 'Totaal 20-29 jaar|2015', 'Totaal 20-29 jaar|2016', 'Totaal 20-29 jaar|2017', 'Totaal 20-29 jaar|2018', 'Totaal 20-29 jaar|2019', 'Totaal 20-29 jaar|2020', 'Totaal 20-29 jaar|2021', 'Totaal 30-39 jaar|2014', 
# ...

# %%
# # Reordering the columns
# merged_dataset = merged_dataset[['NbId', 'NbName', 'DistrictId', 'DistrictName', 'Geoshape', 'GeoshapePerimeter', 'GeoshapeArea',
#                                  'GeoshapeCenter', 'Mannen|2014', 'Mannen|2015', 'Mannen|2016', 'Mannen|2017', 'Mannen|2018', 'Mannen|2019', 'Mannen|2020', 'Mannen|2021', 'Vrouwen|2014', 'Vrouwen|2015', 'Vrouwen|2016', 'Vrouwen|2017', 'Vrouwen|2018', 'Vrouwen|2019', 'Vrouwen|2020', 'Vrouwen|2021', 'Totaal 0-9 jaar|2014', 'Totaal 0-9 jaar|2015', 'Totaal 0-9 jaar|2016', 'Totaal 0-9 jaar|2017', 'Totaal 0-9 jaar|2018', 'Totaal 0-9 jaar|2019', 'Totaal 0-9 jaar|2020', 'Totaal 0-9 jaar|2021', 'Totaal 10-19 jaar|2014', 'Totaal 10-19 jaar|2015', 'Totaal 10-19 jaar|2016', 'Totaal 10-19 jaar|2017', 'Totaal 10-19 jaar|2018', 'Totaal 10-19 jaar|2019', 'Totaal 10-19 jaar|2020', 'Totaal 10-19 jaar|2021', 'Totaal 20-29 jaar|2014', 'Totaal 20-29 jaar|2015', 'Totaal 20-29 jaar|2016', 'Totaal 20-29 jaar|2017', 'Totaal 20-29 jaar|2018', 'Totaal 20-29 jaar|2019', 'Totaal 20-29 jaar|2020', 'Totaal 20-29 jaar|2021', 'Totaal 30-39 jaar|2014', 'Totaal 30-39 jaar|2015', 'Totaal 30-39 jaar|2016', 'Totaal 30-39 jaar|2017', 'Totaal 30-39 jaar|2018', 'Totaal 30-39 jaar|2019', 'Totaal 30-39 jaar|2020', 'Totaal 30-39 jaar|2021', 'Totaal 40-49 jaar|2014', 'Totaal 40-49 jaar|2015', 'Totaal 40-49 jaar|2016', 'Totaal 40-49 jaar|2017', 'Totaal 40-49 jaar|2018', 'Totaal 40-49 jaar|2019', 'Totaal 40-49 jaar|2020', 'Totaal 40-49 jaar|2021', 'Totaal 50-59 jaar|2014', 'Totaal 50-59 jaar|2015', 'Totaal 50-59 jaar|2016', 'Totaal 50-59 jaar|2017', 'Totaal 50-59 jaar|2018', 'Totaal 50-59 jaar|2019', 'Totaal 50-59 jaar|2020', 'Totaal 50-59 jaar|2021', 'Totaal 60-69 jaar|2014', 'Totaal 60-69 jaar|2015', 'Totaal 60-69 jaar|2016', 'Totaal 60-69 jaar|2017', 'Totaal 60-69 jaar|2018', 'Totaal 60-69 jaar|2019', 'Totaal 60-69 jaar|2020', 'Totaal 60-69 jaar|2021', 'Totaal 70-79 jaar|2014', 'Totaal 70-79 jaar|2015', 'Totaal 70-79 jaar|2016', 'Totaal 70-79 jaar|2017', 'Totaal 70-79 jaar|2018', 'Totaal 70-79 jaar|2019', 'Totaal 70-79 jaar|2020', 'Totaal 70-79 jaar|2021', 'Totaal 80-89 jaar|2014', 'Totaal 80-89 jaar|2015', 'Totaal 80-89 jaar|2016', 'Totaal 80-89 jaar|2017', 'Totaal 80-89 jaar|2018', 'Totaal 80-89 jaar|2019', 'Totaal 80-89 jaar|2020', 'Totaal 80-89 jaar|2021', 'Totaal 90 jaar en ouder|2014', 'Totaal 90 jaar en ouder|2015', 'Totaal 90 jaar en ouder|2016', 'Totaal 90 jaar en ouder|2017', 'Totaal 90 jaar en ouder|2018', 'Totaal 90 jaar en ouder|2019', 'Totaal 90 jaar en ouder|2020', 'Totaal 90 jaar en ouder|2021', 'Nederland|2014', 'Nederland|2015', 'Nederland|2016', 'Nederland|2017', 'Nederland|2018', 'Nederland|2019', 'Nederland|2020', 'Nederland|2021', 'Westerse migratieherkomst|2014', 'Westerse migratieherkomst|2015', 'Westerse migratieherkomst|2016', 'Westerse migratieherkomst|2017', 'Westerse migratieherkomst|2018', 'Westerse migratieherkomst|2019', 'Westerse migratieherkomst|2020', 'Westerse migratieherkomst|2021', 'Niet westerse migratieherkomst|2014', 'Niet westerse migratieherkomst|2015', 'Niet westerse migratieherkomst|2016', 'Niet westerse migratieherkomst|2017', 'Niet westerse migratieherkomst|2018', 'Niet westerse migratieherkomst|2019', 'Niet westerse migratieherkomst|2020', 'Niet westerse migratieherkomst|2021', 'levendgeborenen|2014', 'levendgeborenen|2015', 'levendgeborenen|2016', 'levendgeborenen|2017', 'levendgeborenen|2018', 'levendgeborenen|2019', 'levendgeborenen|2020', 'levendgeborenen|2021', 'overledenen|2014', 'overledenen|2015', 'overledenen|2016', 'overledenen|2017', 'overledenen|2018', 'overledenen|2019', 'overledenen|2020', 'overledenen|2021', 'Totaal aantal huishoudens|2014', 'Totaal aantal huishoudens|2015', 'Totaal aantal huishoudens|2016', 'Totaal aantal huishoudens|2017', 'Totaal aantal huishoudens|2018', 'Totaal aantal huishoudens|2019', 'Totaal aantal huishoudens|2020', 'Totaal aantal huishoudens|2021', 'Eenpersoonshuishoudens|2014', 'Eenpersoonshuishoudens|2015', 'Eenpersoonshuishoudens|2016', 'Eenpersoonshuishoudens|2017', 'Eenpersoonshuishoudens|2018', 'Eenpersoonshuishoudens|2019', 'Eenpersoonshuishoudens|2020', 'Eenpersoonshuishoudens|2021', 'Huishoudens zonder kinderen|2014', 'Huishoudens zonder kinderen|2015', 'Huishoudens zonder kinderen|2016', 'Huishoudens zonder kinderen|2017', 'Huishoudens zonder kinderen|2018', 'Huishoudens zonder kinderen|2019', 'Huishoudens zonder kinderen|2020', 'Huishoudens zonder kinderen|2021', 'Huishoudens met kinderen|2014', 'Huishoudens met kinderen|2015', 'Huishoudens met kinderen|2016', 'Huishoudens met kinderen|2017', 'Huishoudens met kinderen|2018', 'Huishoudens met kinderen|2019', 'Huishoudens met kinderen|2020', 'Huishoudens met kinderen|2021', 'Gemiddelde huishoudensgrootte|2014', 'Gemiddelde huishoudensgrootte|2015', 'Gemiddelde huishoudensgrootte|2016', 'Gemiddelde huishoudensgrootte|2017', 'Gemiddelde huishoudensgrootte|2018', 'Gemiddelde huishoudensgrootte|2019', 'Gemiddelde huishoudensgrootte|2020', 'Gemiddelde huishoudensgrootte|2021', 'sport wekelijks (18-84 jaar)|2014', 'sport wekelijks (18-84 jaar)|2015', 'sport wekelijks (18-84 jaar)|2016', 'sport wekelijks (18-84 jaar)|2017', 'sport wekelijks (18-84 jaar)|2018', 'sport wekelijks (18-84 jaar)|2019', 'sport wekelijks (18-84 jaar)|2020', 'sport wekelijks (18-84 jaar)|2021', 'hoog huishoudinkomen (20%) %|2014', 'hoog huishoudinkomen (20%) %|2015', 'hoog huishoudinkomen (20%) %|2016', 'hoog huishoudinkomen (20%) %|2017', 'hoog huishoudinkomen (20%) %|2018', 'hoog huishoudinkomen (20%) %|2019', 'hoog huishoudinkomen (20%) %|2020', 'hoog huishoudinkomen (20%) %|2021']]

# %%
desired_columns = [
    'NbId', 'NbName', 'DistrictId', 'DistrictName', 'Geoshape', 'GeoshapePerimeter', 'GeoshapeArea',
    'GeoshapeCenter'
] + [f'Mannen|{year}' for year in range(2014, 2022)] + [f'Vrouwen|{year}' for year in range(2014, 2022)] + \
    [f'Totaal {age_range} jaar|{year}' for age_range in ['0-9', '10-19', '20-29', '30-39', '40-49', '50-59', '60-69', '70-79', '80-89'] for year in range(2014, 2022)] + \
    [f'Totaal 90 jaar en ouder|{year}' for year in range(2014, 2022)]

selected_columns_dataset = merged_dataset[desired_columns]

# Display the first few rows of the dataset with selected columns
selected_columns_dataset.head()

# %%
merged_dataset.to_csv('timed_data-Iris-Complete.csv', index=False)
